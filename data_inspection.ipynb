# %%
import pickle
import os
import matplotlib.pyplot as plt

# %%
# path = 'data/stack-towers-train'
path = 'data/stack-boxes-train'
data_type = 'color'
fname = '000004-14.pkl'
data = pickle.load(open(os.path.join(path, data_type, fname), 'rb'))
print(data.shape)
# Out:
# (9, 4, 480, 640, 3)

# %%
step = -1
cam_view = 0

# display rgb image
plt.imshow(data[step, cam_view, :, :, :])
